# %% [markdown]
# # 1. 매출데이터 구축

# %% [markdown]
# ## 파일 불러오기

# %%
import os

# 필요한 파일의 리스트를 만듭니다.

path_dir = 'C:/Users/CSEL/workspace/jupyter_programming/lesson/invest_data_anal/data/'
folder_list = os.listdir(path_dir)
file_list = [os.listdir(path_dir+folder)[3] for folder in folder_list]
print(file_list)
# Out:
# ['2016_1분기보고서_03_포괄손익계산서_연결_20210317.txt', '2016_반기보고서_03_포괄손익계산서_연결_20210317.txt', '2016_3분기보고서_03_포괄손익계산서_연결_20210317.txt', '2016_사업보고서_03_포괄손익계산서_연결_20210825.txt', '2017_1분기보고서_03_포괄손익계산서_연결_20210901.txt', '2017_반기보고서_03_포괄손익계산서_연결_20210901.txt', '2017_3분기보고서_03_포괄손익계산서_연결_20210901.txt', '2017_사업보고서_03_포괄손익계산서_연결_20210901.txt', '2018_1분기보고서_03_포괄손익계산서_연결_20210901.txt', '2018_반기보고서_03_포괄손익계산서_연결_20210901.txt', '2018_3분기보고서_03_포괄손익계산서_연결_20210901.txt', '2018_사업보고서_03_포괄손익계산서_연결_20210901.txt', '2019_1분기보고서_03_포괄손익계산서_연결_20210901.txt', '2019_반기보고서_03_포괄손익계산서_연결_20210901.txt', '2019_3분기보고서_03_포괄손익계산서_연결_20210701.txt', '2019_사업보고서_03_포괄손익계산서_연결_20210818.txt', '2020_1분기보고서_03_포괄손익계산서_연결_20210620.txt', '2020_반기보고서_03_포괄손익계산서_연결_20210818.txt', '2020_3분기보고서_03_포괄손익계산서_연결_20210708.txt', '2020_사업보고서_03_포괄손익계산서_연결_20210902.txt', '2021_1분기보고서_03_포괄손익계산서_연결_20210908.txt', '2021_반기보고서_03_포괄손익계산서_연결_20210902.txt']

# %% [markdown]
# ## 파일 합치기

# %%
import pandas as pd
from tqdm import tqdm

# 파일을 읽고 데이터 프레임으로 합칩니다.

df = pd.DataFrame()
for i in tqdm(range(len(file_list))):
    filepath = path_dir + folder_list[i] + '/' + file_list[i]
    df_raw = pd.read_csv(filepath, sep='\t', encoding='cp949')
    df = pd.concat([df, df_raw])
df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 22/22 [00:16<00:00,  1.30it/s]
#                                        재무제표종류      종목코드 회사명       시장구분   업종  \
# 0          포괄손익계산서, 기능별 분류(세후기타포괄손익) - 연결재무제표  [060310]  3S  코스닥시장상장법인  262
# 1          포괄손익계산서, 기능별 분류(세후기타포괄손익) - 연결재무제표  [060310]  3S  코스닥시장상장법인  262
# 2          포괄손익계산서, 기능별 분류(세후기타포괄손익) - 연결재무제표  [060310]  3S  코스닥시장상장법인  262
# 3          포괄손익계산서, 기능별 분류(세후기타포괄손익) - 연결재무제표  [060310]  3S  코스닥시장상장법인  262
# 4          포괄손익계산서, 기능별 분류(세후기타포괄손익) - 연결재무제표  [060310]  3S  코스닥시장상장법인  262
# ...                                       ...       ...  ..        ...  ...
# 49315  포괄손익계산서, 성격별 분류(세전기타포괄손익) - 연결재무제표(선택)  [238490]  힘스  코스닥시장상장법인  292
# 49316  포괄손익계산서, 성격별 분류(세전기타포괄손익) - 연결재무제표(선택)  [238490]  힘스  코스닥시장상장법인  292
# 49317  포괄손익계산서, 성격별 분류(세전기타포괄손익) - 연결재무제표(선택)  [238490]  힘스  코스닥시장상장법인  292
# 49318  포괄손익계산서, 성격별 분류(세전기타포괄손익) - 연결재무제표(선택)  [238490]  힘스  코스닥시장상장법인  292
# 49319  포괄손익계산서, 성격별 분류(세전기타포괄손익) - 연결재무제표(선택)  [238490]  힘스  코스닥시장상장법인  292
#
#                  업종명  결산월       결산기준일   보고서종류   통화  ...        전기 반기 누적  \
# 0           전자부품 제조업    3  2016-06-30  1분기보고서  KRW  ...             NaN
# 1           전자부품 제조업    3  2016-06-30  1분기보고서  KRW  ...             NaN
# 2           전자부품 제조업    3  2016-06-30  1분기보고서  KRW  ...             NaN
# 3           전자부품 제조업    3  2016-06-30  1분기보고서  KRW  ...             NaN
# 4           전자부품 제조업    3  2016-06-30  1분기보고서  KRW  ...             NaN
# ...              ...  ...         ...     ...  ...  ...             ...
# 49315  특수 목적용 기계 제조업   12  2021-06-30   반기보고서  KRW  ...             NaN
# 49316  특수 목적용 기계 제조업   12  2021-06-30   반기보고서  KRW  ...  18,294,058,308
# 49317  특수 목적용 기계 제조업   12  2021-06-30   반기보고서  KRW  ...             NaN
# 49318  특수 목적용 기계 제조업   12  2021-06-30   반기보고서  KRW  ...           3,142
# 49319  특수 목적용 기계 제조업   12  2021-06-30   반기보고서  KRW  ...           3,142
#
#       당기 3분기 3개월 당기 3분기 누적 전기 3분기 3개월 전기 3분기 누적 Unnamed: 12   당기 Unnamed: 14  \
# 0            NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 1            NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 2            NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 3            NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 4            NaN       NaN        NaN       NaN         NaN  NaN         NaN
# ...          ...       ...        ...       ...         ...  ...         ...
# 49315        NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 49316        NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 49317        NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 49318        NaN       NaN        NaN       NaN         NaN  NaN         NaN
# 49319        NaN       NaN        NaN       NaN         NaN  NaN         NaN
#
#       Unnamed: 15 Unnamed: 18
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 49315         NaN         NaN
# 49316         NaN         NaN
# 49317         NaN         NaN
# 49318         NaN         NaN
# 49319         NaN         NaN
#
# [1019439 rows x 31 columns]

# %% [markdown]
# ## 데이터 전처리

# %%
# 코스닥만 가져옵니다.

df = df[df['시장구분'].isin(['코스닥시장상장법인'])]
len(df['회사명'].unique()) # 코스닥 상장 회사의 개수입니다.
# Out:
# 1514

# %%
# 현재 데이터에 매출액이 여러가지 이름으로 되어있습니다. 이를 바꿔줍니다.

df.replace({'수익(매출액)': '매출액', '매출':'매출액'}, inplace=True)
# Out:
# C:\Users\CSEL\anaconda3\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
# 항목멍이 매출액인 부분만 가져옵니다.

df = df[df['항목명'].isin(['매출액'])]
df['당기 1분기 3개월']
# Out:
# 0          7,289,429,497
# 108       44,280,168,458
# 200       53,032,119,775
# 274      313,536,534,178
# 325      543,957,985,765
#               ...
# 49118                NaN
# 49177                NaN
# 49201                NaN
# 49271                NaN
# 49297                NaN
# Name: 당기 1분기 3개월, Length: 18830, dtype: object

# %%
# 각 열마다 눌값이 있다는 것을 확인합니다.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18830 entries, 0 to 49297
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   재무제표종류       18830 non-null  object
#  1   종목코드         18830 non-null  object
#  2   회사명          18830 non-null  object
#  3   시장구분         18830 non-null  object
#  4   업종           18830 non-null  int64
#  5   업종명          18830 non-null  object
#  6   결산월          18830 non-null  int64
#  7   결산기준일        18830 non-null  object
#  8   보고서종류        18830 non-null  object
#  9   통화           18830 non-null  object
#  10  항목코드         18830 non-null  object
#  11  항목명          18830 non-null  object
#  12  당기 1분기 3개월   5081 non-null   object
#  13  당기 1분기 누적    5079 non-null   object
#  14  전기 1분기 3개월   5056 non-null   object
#  15  전기 1분기 누적    5056 non-null   object
#  16  전기           7217 non-null   object
#  17  전전기          7123 non-null   object
#  18  당기 반기 3개월    5124 non-null   object
#  19  당기 반기 누적     5125 non-null   object
#  20  전기 반기 3개월    5107 non-null   object
#  21  전기 반기 누적     5108 non-null   object
#  22  당기 3분기 3개월   4248 non-null   object
#  23  당기 3분기 누적    4250 non-null   object
#  24  전기 3분기 3개월   4236 non-null   object
#  25  전기 3분기 누적    4237 non-null   object
#  26  Unnamed: 12  0 non-null      float64
#  27  당기           4355 non-null   object
#  28  Unnamed: 14  0 non-null      float64
#  29  Unnamed: 15  0 non-null      float64
#  30  Unnamed: 18  0 non-null      float64
# dtypes: float64(4), int64(2), object(25)
# memory usage: 4.6+ MB

# %%
# 눌값을 다 문자열 0으로 채워줍니다.

df.fillna('0', inplace=True) # inplace = True를 잊으면 안 됩니다!
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18830 entries, 0 to 49297
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   재무제표종류       18830 non-null  object
#  1   종목코드         18830 non-null  object
#  2   회사명          18830 non-null  object
#  3   시장구분         18830 non-null  object
#  4   업종           18830 non-null  int64
#  5   업종명          18830 non-null  object
#  6   결산월          18830 non-null  int64
#  7   결산기준일        18830 non-null  object
#  8   보고서종류        18830 non-null  object
#  9   통화           18830 non-null  object
#  10  항목코드         18830 non-null  object
#  11  항목명          18830 non-null  object
#  12  당기 1분기 3개월   18830 non-null  object
#  13  당기 1분기 누적    18830 non-null  object
#  14  전기 1분기 3개월   18830 non-null  object
#  15  전기 1분기 누적    18830 non-null  object
#  16  전기           18830 non-null  object
#  17  전전기          18830 non-null  object
#  18  당기 반기 3개월    18830 non-null  object
#  19  당기 반기 누적     18830 non-null  object
#  20  전기 반기 3개월    18830 non-null  object
#  21  전기 반기 누적     18830 non-null  object
#  22  당기 3분기 3개월   18830 non-null  object
#  23  당기 3분기 누적    18830 non-null  object
#  24  전기 3분기 3개월   18830 non-null  object
#  25  전기 3분기 누적    18830 non-null  object
#  26  Unnamed: 12  18830 non-null  object
#  27  당기           18830 non-null  object
#  28  Unnamed: 14  18830 non-null  object
#  29  Unnamed: 15  18830 non-null  object
#  30  Unnamed: 18  18830 non-null  object
# dtypes: int64(2), object(29)
# memory usage: 4.6+ MB

# %%
# 현재 금액에 쉼표가 있고 문자열입니다. 쉼표를 없애고 정수형으로 바꿔줍니다. 

for i in df.columns[12:]:
    df[i] = df[i].str.replace(',', '').astype('int64')

# %%
# 잘 바뀌었는지 확인해 봅니다. 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18830 entries, 0 to 49297
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   재무제표종류       18830 non-null  object
#  1   종목코드         18830 non-null  object
#  2   회사명          18830 non-null  object
#  3   시장구분         18830 non-null  object
#  4   업종           18830 non-null  int64
#  5   업종명          18830 non-null  object
#  6   결산월          18830 non-null  int64
#  7   결산기준일        18830 non-null  object
#  8   보고서종류        18830 non-null  object
#  9   통화           18830 non-null  object
#  10  항목코드         18830 non-null  object
#  11  항목명          18830 non-null  object
#  12  당기 1분기 3개월   18830 non-null  int64
#  13  당기 1분기 누적    18830 non-null  int64
#  14  전기 1분기 3개월   18830 non-null  int64
#  15  전기 1분기 누적    18830 non-null  int64
#  16  전기           18830 non-null  int64
#  17  전전기          18830 non-null  int64
#  18  당기 반기 3개월    18830 non-null  int64
#  19  당기 반기 누적     18830 non-null  int64
#  20  전기 반기 3개월    18830 non-null  int64
#  21  전기 반기 누적     18830 non-null  int64
#  22  당기 3분기 3개월   18830 non-null  int64
#  23  당기 3분기 누적    18830 non-null  int64
#  24  전기 3분기 3개월   18830 non-null  int64
#  25  전기 3분기 누적    18830 non-null  int64
#  26  Unnamed: 12  18830 non-null  int64
#  27  당기           18830 non-null  int64
#  28  Unnamed: 14  18830 non-null  int64
#  29  Unnamed: 15  18830 non-null  int64
#  30  Unnamed: 18  18830 non-null  int64
# dtypes: int64(21), object(10)
# memory usage: 4.6+ MB

# %%
# 맨처음 1514개 보다 줄었음을 확인할 수 있습니다.

len(df['종목코드'].unique())
# Out:
# 1147

# %%
# 우리한테 필요한 열만 가져오기 위해 어떤 열들이 있는지 봅니다. 

df.columns
# Out:
# Index(['재무제표종류', '종목코드', '회사명', '시장구분', '업종', '업종명', '결산월', '결산기준일', '보고서종류',
#        '통화', '항목코드', '항목명', '당기 1분기 3개월', '당기 1분기 누적', '전기 1분기 3개월',
#        '전기 1분기 누적', '전기', '전전기', '당기 반기 3개월', '당기 반기 누적', '전기 반기 3개월',
#        '전기 반기 누적', '당기 3분기 3개월', '당기 3분기 누적', '전기 3분기 3개월', '전기 3분기 누적',
#        'Unnamed: 12', '당기', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 18'],
#       dtype='object')

# %%
# 매 분기마다 각 매출이 있지만 4분기는 없기 때문에 관련 열들을 이용해 계산을 해줍니다. 

df['4분기 매출'] = df['당기']-df['당기 3분기 누적']
df['4분기 매출']
# Out:
# 0        0
# 108      0
# 200      0
# 274      0
# 325      0
#         ..
# 49118    0
# 49177    0
# 49201    0
# 49271    0
# 49297    0
# Name: 4분기 매출, Length: 18830, dtype: int64

# %% [markdown]
# ## 매출열

# %%
# 매출열을 계산해줍니다.

df['매출'] = df['당기 1분기 3개월']+df['당기 반기 3개월']+df['당기 3분기 3개월']+df['4분기 매출']

# %%
df['매출']
# Out:
# 0          7289429497
# 108       44280168458
# 200       53032119775
# 274      313536534178
# 325      543957985765
#              ...
# 49118     64528228594
# 49177     38873306131
# 49201     17593855449
# 49271     53066885485
# 49297     14419272683
# Name: 매출, Length: 18830, dtype: int64

# %% [markdown]
# ## 최종 매출데이터 구축

# %%
# 종목코드, 회사명, 업종명, 결산기준일
df_sale = df[['종목코드', '회사명', '업종명', '결산기준일', '매출']] # 원하는 데이터만 가져오기
df_sale.index = [i for i in range(len(df['매출']))] # index를 새로 지정
df_sale['종목코드'] = [i[1:-1] for i in df_sale['종목코드']] # 종목코드 수정
df_sale['분기'] = pd.PeriodIndex(df_sale['결산기준일'], freq='Q') # 분기 열 만들기 
df_sale
# Out:
# <ipython-input-15-b547c610337b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sale['종목코드'] = [i[1:-1] for i in df_sale['종목코드']] # 종목코드 수정
# <ipython-input-15-b547c610337b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sale['분기'] = pd.PeriodIndex(df_sale['결산기준일'], freq='Q') # 분기 열 만들기
#          종목코드      회사명                       업종명       결산기준일            매출  \
# 0      060310       3S                  전자부품 제조업  2016-06-30    7289429497
# 1      054620    AP시스템             특수 목적용 기계 제조업  2016-03-31   44280168458
# 2      032040  C&S자산관리              기타 사업지원 서비스업  2016-03-31   53032119775
# 3      130960   CJ E&M                  텔레비전 방송업  2016-03-31  313536534178
# 4      035760    CJ오쇼핑                  텔레비전 방송업  2016-03-31  543957985765
# ...       ...      ...                       ...         ...           ...
# 18825  145020       휴젤     기초 의약물질 및 생물학적 제제 제조업  2021-06-30   64528228594
# 18826  010240       흥국             특수 목적용 기계 제조업  2021-06-30   38873306131
# 18827  189980   흥국에프엔비           비알코올음료 및 얼음 제조업  2021-06-30   17593855449
# 18828  037440       희림  건축기술, 엔지니어링 및 관련 기술 서비스업  2021-06-30   53066885485
# 18829  238490       힘스             특수 목적용 기계 제조업  2021-06-30   14419272683
#
#            분기
# 0      2016Q2
# 1      2016Q1
# 2      2016Q1
# 3      2016Q1
# 4      2016Q1
# ...       ...
# 18825  2021Q2
# 18826  2021Q2
# 18827  2021Q2
# 18828  2021Q2
# 18829  2021Q2
#
# [18830 rows x 6 columns]

# %% [markdown]
# # 2. 지표데이터 구축

# %%
from pykrx import stock
import time
import pandas as pd
import OpenDartReader
import pandas as pd
from tqdm import tqdm
api_key = '6655d5a62b916e96636cab74f8e7e0b05692b825'
dart = OpenDartReader(api_key)

# %%
# KOSDAQ 종목코드 조회
stock_code = stock.get_market_ticker_list(date="20210520", market="KOSDAQ")
(stock_code[:6], len(stock_code))
# Out:
# (['060310', '054620', '265520', '211270', '035760', '051500'], 1503)

# %%
def asset_f(year, corp_code, report_code):
    fs = dart.finstate_all(corp=corp_code, bsns_year=year, fs_div='OFS', reprt_code=report_code) 
    try:
        equity = int(fs.loc[fs['sj_div'].isin(['BS']) & fs['account_id'].isin(['ifrs-full_Equity']), 'thstrm_amount'].replace(",", "")) # 당기자본(자본총계)
        liability = int(fs.loc[fs['sj_div'].isin(['BS']) & fs['account_id'].isin(['ifrs-full_Liabilities']), 'thstrm_amount'].replace(",", "")) # 당기부채(부채총계)
        assets = equity + liability # 자산총계
        return assets
    except:
        equity = int(fs.loc[fs['sj_div'].isin(['BS']) & fs['account_id'].isin(['ifrs_Equity']), 'thstrm_amount'].replace(",", "")) # 당기자본(자본총계)
        liability = int(fs.loc[fs['sj_div'].isin(['BS']) & fs['account_id'].isin(['ifrs_Liabilities']), 'thstrm_amount'].replace(",", "")) # 당기부채(부채총계)
        assets = equity + liability # 자산총계
        return assets

stock_code = stock.get_market_ticker_list(date="20210520", market="KOSDAQ") # 현재일자 기준 가장 가까운 영업일의 코스닥 상장종목 리스트
res = pd.DataFrame()
start_date = '20200917'
end_date = '20200918'
for ticker in tqdm(stock_code[:100]):
    df1 = stock.get_market_ohlcv_by_date(fromdate=start_date, todate=end_date, ticker=ticker) # 기본
    df2 = stock.get_market_fundamental_by_date(fromdate=start_date, todate=end_date, ticker=ticker) # 계산값
    df = pd.concat([df1, df2], axis=1)
    df = df.assign(종목코드=ticker, 종목명=stock.get_market_ticker_name(ticker))
    res = pd.concat([res, df], axis=0)
    time.sleep(1)
res = res.reset_index()
res
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [01:51<00:00,  1.11s/it]
#             날짜     시가     고가     저가     종가     거래량      BPS    PER   PBR  \
# 0   2020-09-17   2270   2270   2210   2230  184640    745.0   0.00  2.99
# 1   2020-09-18   2230   2250   2215   2235   80301    745.0   0.00  3.00
# 2   2020-09-17  10150  10150   9510   9550  630996  10530.0   0.00  0.91
# 3   2020-09-18   9530   9680   9180   9300  485795  10530.0   0.00  0.88
# 4   2020-09-17  23500  23650  22850  22950  166167   7468.0  34.20  3.07
# ..         ...    ...    ...    ...    ...     ...      ...    ...   ...
# 189 2020-09-18   6211   6309   6034   6241  148848  10477.0   5.18  0.61
# 190 2020-09-17    709    719    700    700  168227    287.0   0.00  2.44
# 191 2020-09-18    702    709    698    705   65655    287.0   0.00  2.46
# 192 2020-09-17   7213   7222   7000   7019  290115   2936.0   0.00  2.70
# 193 2020-09-18   7018   7080   6947   6992  170610   2936.0   0.00  2.69
#
#         EPS   DIV    DPS    종목코드      종목명
# 0       0.0  0.00    0.0  060310       3S
# 1       0.0  0.00    0.0  060310       3S
# 2       0.0  0.00    0.0  054620   APS홀딩스
# 3       0.0  0.00    0.0  054620   APS홀딩스
# 4     671.0  0.22   50.0  265520    AP시스템
# ..      ...   ...    ...     ...      ...
# 189  1227.0  1.57  100.0  078890    가온미디어
# 190     0.0  0.00    0.0  036620  감성코퍼레이션
# 191     0.0  0.00    0.0  036620  감성코퍼레이션
# 192     0.0  0.00    0.0  217730  강스템바이오텍
# 193     0.0  0.00    0.0  217730  강스템바이오텍
#
# [194 rows x 14 columns]

# %%
res['분기'] = pd.PeriodIndex(res['날짜'], freq='Q')
res
# Out:
#             날짜     시가     고가     저가     종가     거래량      BPS    PER   PBR  \
# 0   2020-09-17   2270   2270   2210   2230  184640    745.0   0.00  2.99
# 1   2020-09-18   2230   2250   2215   2235   80301    745.0   0.00  3.00
# 2   2020-09-17  10150  10150   9510   9550  630996  10530.0   0.00  0.91
# 3   2020-09-18   9530   9680   9180   9300  485795  10530.0   0.00  0.88
# 4   2020-09-17  23500  23650  22850  22950  166167   7468.0  34.20  3.07
# ..         ...    ...    ...    ...    ...     ...      ...    ...   ...
# 189 2020-09-18   6211   6309   6034   6241  148848  10477.0   5.18  0.61
# 190 2020-09-17    709    719    700    700  168227    287.0   0.00  2.44
# 191 2020-09-18    702    709    698    705   65655    287.0   0.00  2.46
# 192 2020-09-17   7213   7222   7000   7019  290115   2936.0   0.00  2.70
# 193 2020-09-18   7018   7080   6947   6992  170610   2936.0   0.00  2.69
#
#         EPS   DIV    DPS    종목코드      종목명      분기
# 0       0.0  0.00    0.0  060310       3S  2020Q3
# 1       0.0  0.00    0.0  060310       3S  2020Q3
# 2       0.0  0.00    0.0  054620   APS홀딩스  2020Q3
# 3       0.0  0.00    0.0  054620   APS홀딩스  2020Q3
# 4     671.0  0.22   50.0  265520    AP시스템  2020Q3
# ..      ...   ...    ...     ...      ...     ...
# 189  1227.0  1.57  100.0  078890    가온미디어  2020Q3
# 190     0.0  0.00    0.0  036620  감성코퍼레이션  2020Q3
# 191     0.0  0.00    0.0  036620  감성코퍼레이션  2020Q3
# 192     0.0  0.00    0.0  217730  강스템바이오텍  2020Q3
# 193     0.0  0.00    0.0  217730  강스템바이오텍  2020Q3
#
# [194 rows x 15 columns]

# %%
res_unique = res.drop_duplicates(['종목코드', '분기'])
res_unique.reset_index(drop=True, inplace=True)  
res_unique
# Out:
#            날짜      시가      고가      저가      종가     거래량       BPS     PER   PBR  \
# 0  2020-09-17    2270    2270    2210    2230  184640     745.0    0.00  2.99
# 1  2020-09-17   10150   10150    9510    9550  630996   10530.0    0.00  0.91
# 2  2020-09-17   23500   23650   22850   22950  166167    7468.0   34.20  3.07
# 3  2020-09-17    7500    7570    7360    7360   28713    5479.0  144.31  1.34
# 4  2020-09-17  144600  146500  141000  142300  304413  134364.0   26.80  1.06
# ..        ...     ...     ...     ...     ...     ...       ...     ...   ...
# 92 2020-09-17    2890    2900    2830    2860  122533    2270.0   30.75  1.26
# 93 2020-09-17   16800   16800   16250   16250  214600    5410.0   19.67  3.00
# 94 2020-09-17    6407    6407    6191    6201  198649   10477.0    5.15  0.60
# 95 2020-09-17     709     719     700     700  168227     287.0    0.00  2.44
# 96 2020-09-17    7213    7222    7000    7019  290115    2936.0    0.00  2.70
#
#        EPS   DIV     DPS    종목코드      종목명      분기
# 0      0.0  0.00     0.0  060310       3S  2020Q3
# 1      0.0  0.00     0.0  054620   APS홀딩스  2020Q3
# 2    671.0  0.22    50.0  265520    AP시스템  2020Q3
# 3     51.0  0.95    70.0  211270     AP위성  2020Q3
# 4   5310.0  0.98  1400.0  035760   CJ ENM  2020Q3
# ..     ...   ...     ...     ...      ...     ...
# 92    93.0  0.00     0.0  052220     iMBC  2020Q3
# 93   826.0  0.25    40.0  079940      가비아  2020Q3
# 94  1227.0  1.58   100.0  078890    가온미디어  2020Q3
# 95     0.0  0.00     0.0  036620  감성코퍼레이션  2020Q3
# 96     0.0  0.00     0.0  217730  강스템바이오텍  2020Q3
#
# [97 rows x 15 columns]

# %%
quater = {'Q1': '11013',
          'Q2': '11012',
          'Q3': '11014',
          'Q4': '11011'}
res_unique['자산'] = ['' for i in range(len(res_unique['분기']))]
for i in tqdm(range(len(res_unique['자산']))):
    try:
        year = str(res_unique['분기'][i])[:4] # 년도 
        c_code = res_unique['종목코드'][i] # 회사 코드
        q_code = quater[str(res_unique['분기'][i])[-2:]] #분기 코드
        res_unique['자산'][i] = asset_f(year, c_code, q_code)
    except:
        res_unique['자산'][i] = ''
res_unique
# Out:
# <ipython-input-21-bbe6871f3576>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_unique['자산'] = ['' for i in range(len(res_unique['분기']))]
#   0%|                                                                                           | 0/97 [00:00<?, ?it/s]<ipython-input-21-bbe6871f3576>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_unique['자산'][i] = asset_f(year, c_code, q_code)
# C:\Users\CSEL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  11%|█████████▎                                                                        | 11/97 [00:00<00:07, 12.09it/s]<ipython-input-21-bbe6871f3576>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_unique['자산'][i] = ''
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [00:07<00:00, 12.25it/s]
#            날짜      시가      고가      저가      종가     거래량       BPS     PER   PBR  \
# 0  2020-09-17    2270    2270    2210    2230  184640     745.0    0.00  2.99
# 1  2020-09-17   10150   10150    9510    9550  630996   10530.0    0.00  0.91
# 2  2020-09-17   23500   23650   22850   22950  166167    7468.0   34.20  3.07
# 3  2020-09-17    7500    7570    7360    7360   28713    5479.0  144.31  1.34
# 4  2020-09-17  144600  146500  141000  142300  304413  134364.0   26.80  1.06
# ..        ...     ...     ...     ...     ...     ...       ...     ...   ...
# 92 2020-09-17    2890    2900    2830    2860  122533    2270.0   30.75  1.26
# 93 2020-09-17   16800   16800   16250   16250  214600    5410.0   19.67  3.00
# 94 2020-09-17    6407    6407    6191    6201  198649   10477.0    5.15  0.60
# 95 2020-09-17     709     719     700     700  168227     287.0    0.00  2.44
# 96 2020-09-17    7213    7222    7000    7019  290115    2936.0    0.00  2.70
#
#        EPS   DIV     DPS    종목코드      종목명      분기             자산
# 0      0.0  0.00     0.0  060310       3S  2020Q3    50319737982
# 1      0.0  0.00     0.0  054620   APS홀딩스  2020Q3   247306498234
# 2    671.0  0.22    50.0  265520    AP시스템  2020Q3   418710448554
# 3     51.0  0.95    70.0  211270     AP위성  2020Q3   118984357902
# 4   5310.0  0.98  1400.0  035760   CJ ENM  2020Q3  4620708993531
# ..     ...   ...     ...     ...      ...     ...            ...
# 92    93.0  0.00     0.0  052220     iMBC  2020Q3    65225711432
# 93   826.0  0.25    40.0  079940      가비아  2020Q3    93469306923
# 94  1227.0  1.58   100.0  078890    가온미디어  2020Q3   326429804062
# 95     0.0  0.00     0.0  036620  감성코퍼레이션  2020Q3    39114977637
# 96     0.0  0.00     0.0  217730  강스템바이오텍  2020Q3    71606471960
#
# [97 rows x 16 columns]

# %%
res_final = pd.merge(res, res_unique, how='left')
res_final.fillna(method='ffill', inplace=True)
res_final['종목분기'] = res_final['종목코드'] + res_final['분기'].astype('string') 
res_final
# Out:
#             날짜     시가     고가     저가     종가     거래량      BPS    PER   PBR  \
# 0   2020-09-17   2270   2270   2210   2230  184640    745.0   0.00  2.99
# 1   2020-09-18   2230   2250   2215   2235   80301    745.0   0.00  3.00
# 2   2020-09-17  10150  10150   9510   9550  630996  10530.0   0.00  0.91
# 3   2020-09-18   9530   9680   9180   9300  485795  10530.0   0.00  0.88
# 4   2020-09-17  23500  23650  22850  22950  166167   7468.0  34.20  3.07
# ..         ...    ...    ...    ...    ...     ...      ...    ...   ...
# 189 2020-09-18   6211   6309   6034   6241  148848  10477.0   5.18  0.61
# 190 2020-09-17    709    719    700    700  168227    287.0   0.00  2.44
# 191 2020-09-18    702    709    698    705   65655    287.0   0.00  2.46
# 192 2020-09-17   7213   7222   7000   7019  290115   2936.0   0.00  2.70
# 193 2020-09-18   7018   7080   6947   6992  170610   2936.0   0.00  2.69
#
#         EPS   DIV    DPS    종목코드      종목명      분기            자산          종목분기
# 0       0.0  0.00    0.0  060310       3S  2020Q3   50319737982  0603102020Q3
# 1       0.0  0.00    0.0  060310       3S  2020Q3   50319737982  0603102020Q3
# 2       0.0  0.00    0.0  054620   APS홀딩스  2020Q3  247306498234  0546202020Q3
# 3       0.0  0.00    0.0  054620   APS홀딩스  2020Q3  247306498234  0546202020Q3
# 4     671.0  0.22   50.0  265520    AP시스템  2020Q3  418710448554  2655202020Q3
# ..      ...   ...    ...     ...      ...     ...           ...           ...
# 189  1227.0  1.57  100.0  078890    가온미디어  2020Q3  326429804062  0788902020Q3
# 190     0.0  0.00    0.0  036620  감성코퍼레이션  2020Q3   39114977637  0366202020Q3
# 191     0.0  0.00    0.0  036620  감성코퍼레이션  2020Q3   39114977637  0366202020Q3
# 192     0.0  0.00    0.0  217730  강스템바이오텍  2020Q3   71606471960  2177302020Q3
# 193     0.0  0.00    0.0  217730  강스템바이오텍  2020Q3   71606471960  2177302020Q3
#
# [194 rows x 17 columns]

# %%
df_sale['종목분기'] = df_sale['종목코드'] + df_sale['분기'].astype('string')
df_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18830 entries, 0 to 18829
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종목코드    18830 non-null  object
#  1   회사명     18830 non-null  object
#  2   업종명     18830 non-null  object
#  3   결산기준일   18830 non-null  object
#  4   매출      18830 non-null  int64
#  5   분기      18830 non-null  period[Q-DEC]
#  6   종목분기    18830 non-null  string
# dtypes: int64(1), object(4), period[Q-DEC](1), string(1)
# memory usage: 1.1+ MB

# %%
df_sale.reset_index(drop=True, inplace=True)
res_final.reset_index(drop=True, inplace=True)
df = pd.merge(res_final, df_sale, how='left', on='종목분기')
df
# Out:
#             날짜     시가     고가     저가     종가     거래량      BPS    PER   PBR  \
# 0   2020-09-17   2270   2270   2210   2230  184640    745.0   0.00  2.99
# 1   2020-09-18   2230   2250   2215   2235   80301    745.0   0.00  3.00
# 2   2020-09-17  10150  10150   9510   9550  630996  10530.0   0.00  0.91
# 3   2020-09-18   9530   9680   9180   9300  485795  10530.0   0.00  0.88
# 4   2020-09-17  23500  23650  22850  22950  166167   7468.0  34.20  3.07
# ..         ...    ...    ...    ...    ...     ...      ...    ...   ...
# 189 2020-09-18   6211   6309   6034   6241  148848  10477.0   5.18  0.61
# 190 2020-09-17    709    719    700    700  168227    287.0   0.00  2.44
# 191 2020-09-18    702    709    698    705   65655    287.0   0.00  2.46
# 192 2020-09-17   7213   7222   7000   7019  290115   2936.0   0.00  2.70
# 193 2020-09-18   7018   7080   6947   6992  170610   2936.0   0.00  2.69
#
#         EPS  ...      종목명    분기_x            자산          종목분기  종목코드_y  \
# 0       0.0  ...       3S  2020Q3   50319737982  0603102020Q3  060310
# 1       0.0  ...       3S  2020Q3   50319737982  0603102020Q3  060310
# 2       0.0  ...   APS홀딩스  2020Q3  247306498234  0546202020Q3  054620
# 3       0.0  ...   APS홀딩스  2020Q3  247306498234  0546202020Q3  054620
# 4     671.0  ...    AP시스템  2020Q3  418710448554  2655202020Q3  265520
# ..      ...  ...      ...     ...           ...           ...     ...
# 189  1227.0  ...    가온미디어  2020Q3  326429804062  0788902020Q3  078890
# 190     0.0  ...  감성코퍼레이션  2020Q3   39114977637  0366202020Q3  036620
# 191     0.0  ...  감성코퍼레이션  2020Q3   39114977637  0366202020Q3  036620
# 192     0.0  ...  강스템바이오텍  2020Q3   71606471960  2177302020Q3  217730
# 193     0.0  ...  강스템바이오텍  2020Q3   71606471960  2177302020Q3  217730
#
#          회사명                    업종명       결산기준일            매출    분기_y
# 0         3S          특수 목적용 기계 제조업  2020-09-30  6.705135e+09  2020Q3
# 1         3S          특수 목적용 기계 제조업  2020-09-30  6.705135e+09  2020Q3
# 2     APS홀딩스                 기타 금융업  2020-09-30 -1.129233e+10  2020Q3
# 3     APS홀딩스                 기타 금융업  2020-09-30 -1.129233e+10  2020Q3
# 4      AP시스템          특수 목적용 기계 제조업  2020-09-30 -2.495765e+11  2020Q3
# ..       ...                    ...         ...           ...     ...
# 189    가온미디어         통신 및 방송 장비 제조업  2020-09-30 -2.227446e+11  2020Q3
# 190     버추얼텍              기타 전문 도매업  2020-09-30 -6.220328e+09  2020Q3
# 191     버추얼텍              기타 전문 도매업  2020-09-30 -6.220328e+09  2020Q3
# 192  강스템바이오텍  기초 의약물질 및 생물학적 제제 제조업  2020-09-30 -4.468881e+09  2020Q3
# 193  강스템바이오텍  기초 의약물질 및 생물학적 제제 제조업  2020-09-30 -4.468881e+09  2020Q3
#
# [194 rows x 23 columns]
